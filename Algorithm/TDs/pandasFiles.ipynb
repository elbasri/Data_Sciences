# %% [markdown]
# Pandas + Files

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataF = pd.read_csv('data/dataset.csv', sep=";", header = None)
dataF.columns = ["X","Y", "Z"]
dataF
dataF.describe()
# Out:
#           X          Y           Z
# count  50.0  50.000000   50.000000
# mean    1.0  10.480000   53.420000
# std     0.0   6.475196   32.379188
# min     1.0   0.000000    0.000000
# 25%     1.0   6.000000   31.250000
# 50%     1.0  10.500000   54.000000
# 75%     1.0  16.000000   80.000000
# max     1.0  20.000000  102.000000

# %%
plt.scatter(dataF["Y"], dataF["Z"])
plt.show()

# %%
dataF2 = dataF[(dataF["Y"]>10) & (dataF["Y"]<15)]
dataF2
# Out:
#     X   Y   Z         T
# 3   1  13  67  0.988235
# 6   1  11  56  0.983607
# 12  1  13  66  0.988235
# 18  1  13  65  0.988235
# 19  1  11  56  0.983607
# 33  1  13  65  0.988235
# 36  1  11  57  0.983607
# 38  1  12  61  0.986207

# %%
import numpy as np
cosP = lambda x: (x**2 - 1) * np.cos(2 * np.pi / (x**2 +1))
cosP(1)
dataF["T"] = dataF.Z.apply(cosP)
dataF.head(10)
# Out:
#    X   Y   Z            T
# 0  1   9  45  2023.990267
# 1  1   0   0    -1.000000
# 2  1   6  32  1022.980780
# 3  1  13  67  4487.995606
# 4  1  19  97  9407.997903
# 5  1  19  96  9214.997859
# 6  1  11  56  3134.993712
# 7  1  15  77  5927.996672
# 8  1   2  10    98.808494
# 9  1   1   5    23.302604

# %%
plt.scatter(dataF["Z"], dataF["T"])

# %%
def validity(t):
  if t>1500 :
    return "Valide"
  else:
    return "Invalide"

dataF["Validity"] = dataF["T"].apply(validity)
dataF.head(5)
# Out:
#    X   Y   Z            T  Validity
# 0  1   9  45  2023.990267    Valide
# 1  1   0   0    -1.000000  Invalide
# 2  1   6  32  1022.980780  Invalide
# 3  1  13  67  4487.995606    Valide
# 4  1  19  97  9407.997903    Valide

# %%
plt.bar(dataF["Validity"], dataF["T"])
# Out:
# <BarContainer object of 50 artists>

# %%
dataF.Validity.value_counts()
# Out:
# Valide      34
# Invalide    16
# Name: Validity, dtype: int64

# %%
dataF.Validity.value_counts().plot.pie()
# Out:
# <Axes: ylabel='Validity'>
